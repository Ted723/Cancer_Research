# %%
import pandas as pd

# %%
pwd
# Out:
# u'/data/nrnb01_nobackup/agross/TCGA_methylation/iPython_Notebooks'

# %%
ls
# Out:
# cancerlist.txt              Get_Msets.ipynb  Report.ipynb   Untitled0.ipynb
# Get_Methylation_Data.ipynb  Paralllel.ipynb  tar_links.txt  url_list.txt

# %%
cd ../ACC/
# Out:
# /data/nrnb01_nobackup/agross/TCGA_methylation/ACC

# %%
acc_mappings = pd.read_csv('ACC.mappings.csv', index_col=0, usecols=['barcode','TCGA.ID','histology'])
a = acc_mappings
a
# Out:
#                                         TCGA.ID  \
# barcode
# 9283265010_R01C01  TCGA-OR-A5LC-01A-11D-A29J-05
# 9283265010_R02C01  TCGA-OR-A5K8-01A-11D-A29J-05
# 9283265010_R03C01  TCGA-OR-A5JM-01A-11D-A29J-05
# 9283265010_R04C01  TCGA-OR-A5L3-01A-11D-A29J-05
# 9283265010_R05C01  TCGA-OR-A5LR-01A-11D-A29J-05
# 9283265010_R06C01  TCGA-OR-A5LT-01A-11D-A29J-05
# 9283265010_R01C02  TCGA-OR-A5KV-01A-11D-A29J-05
# 9283265010_R02C02  TCGA-OR-A5KO-01A-11D-A29J-05
# 9283265010_R03C02  TCGA-OR-A5J2-01A-11D-A29J-05
# 9283265010_R04C02  TCGA-OR-A5JS-01A-11D-A29J-05
# 9283265010_R05C02  TCGA-OR-A5JI-01A-11D-A29J-05
# 9283265010_R06C02  TCGA-OR-A5K9-01A-11D-A29J-05
# 9283265012_R01C01  TCGA-OR-A5JG-01A-11D-A29J-05
# 9283265012_R02C01  TCGA-OR-A5KW-01A-11D-A29J-05
# 9283265012_R03C01  TCGA-OR-A5J7-01A-11D-A29J-05
# 9283265012_R04C01  TCGA-OR-A5LO-01A-11D-A29J-05
# 9283265012_R05C01  TCGA-OR-A5JO-01A-11D-A29J-05
# 9283265012_R06C01  TCGA-OU-A5PI-01A-12D-A29J-05
# ...

# %%
acc_patient = pd.read_csv('../Minfi_Output/ACC_mset.csv', index_col=0)
acc =acc_patient.head().stack().head()
acc
# Out:
# cg13869341  9283265010_R01C01    0.838821
#             9283265010_R02C01    0.860483
#             9283265010_R03C01    0.885606
#             9283265010_R04C01    0.856034
#             9283265010_R05C01    0.826106
# dtype: float64

# %%
b = acc_patient
c= b.transpose()
c.index.name = 'barcode'
d = c
d
# Out:
#                    cg13869341  cg14008030  cg12045430  cg20826792  cg00381604  \
# barcode
# 9283265010_R01C01    0.838821    0.754150    0.233321    0.362271    0.151602
# 9283265010_R02C01    0.860483    0.644770    0.134562    0.464021    0.140310
# 9283265010_R03C01    0.885606    0.730299    0.292089    0.473111    0.195156
# 9283265010_R04C01    0.856034    0.771222    0.280681    0.613353    0.291057
# 9283265010_R05C01    0.826106    0.584768    0.303479    0.584091    0.163177
# 9283265010_R06C01    0.901290    0.761874    0.145047    0.524802    0.117262
# 9283265010_R01C02    0.791481    0.760869    0.279082    0.456538    0.104102
# 9283265010_R02C02    0.863729    0.724012    0.201869    0.518891    0.133798
# 9283265010_R03C02    0.838324    0.715404    0.262386    0.538791    0.135624
# 9283265010_R04C02    0.795876    0.724481    0.233977    0.460628    0.230947
# 9283265010_R05C02    0.850890    0.795444    0.155497    0.379189    0.202908
# ...

# %%
final = pd.merge(a,d, on=a.index, how='outer')
finals = final.head()
finals.rename(columns={'key_0':'barcode'}, inplace=True)

# %%
#if '01A' in col in finals['TCGA.ID']:
 #   print "Ted"
#else print "Tedd"
# Out:
#   File "<ipython-input-202-95523271d797>", line 3
#     else print "Tedd"
#              ^
# SyntaxError: invalid syntax

# %%
#df2 = finals.filter(regex='barcode')
#df2
# Out:
#              barcode
# 0  9283265010_R01C01
# 1  9283265010_R02C01
# 2  9283265010_R03C01
# 3  9283265010_R04C01
# 4  9283265010_R05C01

# %%
i

# %% [markdown]
# * All except last are solid tumor sample
# * add final[] around whole thing to get the actual dataframe without it

# %%
final['TCGA.ID'].str.contains('01A')==True
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# ...
# 66     True
# 67     True
# 68     True
# 69     True
# 70     True
# 71     True
# 72     True
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# 78     True
# 79     True
# 80    False
# Name: TCGA.ID, Length: 81, dtype: bool

# %%
pattern = r'0[A-Z]'
final['TCGA.ID'].str.contains(pattern)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80     True
# Name: TCGA.ID, Length: 81, dtype: bool

# %%
#finals['check'] = finals['TCGA.ID'].apply(lambda x: 'Yes' for x if ['01A'] in finals['TCGA.ID'])
# Out:
#   File "<ipython-input-129-475a15c9c623>", line 1
#     finals['check'] = finals['TCGA.ID'].apply(lambda x: 'Yes' for x if ['01A'] in finals['TCGA.ID'])
#                                                                      ^
# SyntaxError: invalid syntax

# %%
#z = [col for col in finals['TCGA.ID'] if '01A' in col]
#z
# Out:
# ['TCGA-OR-A5LC-01A-11D-A29J-05',
#  'TCGA-OR-A5K8-01A-11D-A29J-05',
#  'TCGA-OR-A5JM-01A-11D-A29J-05',
#  'TCGA-OR-A5L3-01A-11D-A29J-05',
#  'TCGA-OR-A5LR-01A-11D-A29J-05']

# %% [markdown]
# * this works however will not let me do it for finals, maybe put an else function?

# %%
#finals['checkk'] = [col for col in finals['TCGA.ID'] if '01A' in col else 'ted']
# Out:
#   File "<ipython-input-186-6bbd2bbf84f7>", line 1
#     finals['checkk'] = [col for col in finals['TCGA.ID'] if '01A' in col else 'ted']
#                                                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# *so close! should but doesnt work,..

# %%
#final['realcheck'] = ["Noo" if '-20A-' in final['TCGA.ID'] else col for col in final['TCGA.ID']]

# %%
#final.drop(['realcheck','foreal'], axis=1, inplace=True)

# %%
final['Sample_Type'] = ["Normal" if '-20A-' in col else "Tumor" for col in final['TCGA.ID']]

# %%
final
# Out:
#                 key_0                       TCGA.ID  \
# 0   9283265010_R01C01  TCGA-OR-A5LC-01A-11D-A29J-05
# 1   9283265010_R02C01  TCGA-OR-A5K8-01A-11D-A29J-05
# 2   9283265010_R03C01  TCGA-OR-A5JM-01A-11D-A29J-05
# 3   9283265010_R04C01  TCGA-OR-A5L3-01A-11D-A29J-05
# 4   9283265010_R05C01  TCGA-OR-A5LR-01A-11D-A29J-05
# 5   9283265010_R06C01  TCGA-OR-A5LT-01A-11D-A29J-05
# 6   9283265010_R01C02  TCGA-OR-A5KV-01A-11D-A29J-05
# 7   9283265010_R02C02  TCGA-OR-A5KO-01A-11D-A29J-05
# 8   9283265010_R03C02  TCGA-OR-A5J2-01A-11D-A29J-05
# 9   9283265010_R04C02  TCGA-OR-A5JS-01A-11D-A29J-05
# 10  9283265010_R05C02  TCGA-OR-A5JI-01A-11D-A29J-05
# 11  9283265010_R06C02  TCGA-OR-A5K9-01A-11D-A29J-05
# 12  9283265012_R01C01  TCGA-OR-A5JG-01A-11D-A29J-05
# 13  9283265012_R02C01  TCGA-OR-A5KW-01A-11D-A29J-05
# 14  9283265012_R03C01  TCGA-OR-A5J7-01A-11D-A29J-05
# 15  9283265012_R04C01  TCGA-OR-A5LO-01A-11D-A29J-05
# 16  9283265012_R05C01  TCGA-OR-A5JO-01A-11D-A29J-05
# ...
