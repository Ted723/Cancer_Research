# %% [markdown]
# # Get TCGA Methylation Data

# %% [markdown]
# This notebook illustrates how to retrieve Level 1 TCGA HumanMethylation450k raw data for all available cancertypes, as well as the accompanying auxillary and mage-tab files that allow mapping of clinical patient data to methylation data.
# * BeautifulSoup is used to parse the TCGA HTTPS open access directory for urls to download data.
# * The downloaded tar archives are unzipped and extracted to user specified out_path folder.

# %% [markdown]
# <b>Imports</b>

# %%
from bs4 import BeautifulSoup
import urllib2
from urllib2 import HTTPError
import pandas as pd
import os as oscd 
import StringIO
import gzip
import re
import rpy2

from IPython.display import clear_output

# %% [markdown]
# <b>Directory Currently In:</b>

# %%
# %%bash
# pwd
# ls
# Out:
# /data/nrnb01_nobackup/agross/TCGA_methylation
# FirstTime_Old
# Get_Methylation_Data.ipynb
# Get_Msets.ipynb
# Report.ipynb

# %% [markdown]
# * Change to desired directory

# %%
cd /data/nrnb01_nobackup/agross/TCGA_methylation/
# Out:
# /data/nrnb01_nobackup/agross/TCGA_methylation

# %% [markdown]
# <b>Outpaths</b>

# %% [markdown]
# * Specify paths to certification and to data storage
#     * Change to desired pathways

# %%
PATH_TO_CERT = '/Documents/IdekerLab/BackUp/JustinCase/cacert.pem'
OUT_PATH = '/data/nrnb01_nobackup/agross/TCGA_methylation/'

# %% [markdown]
# <b>Path to Data on TCGA Website</b>

# %%
base_url = 'https://tcga-data.nci.nih.gov/tcgafiles/ftp_auth/distro_ftpusers/anonymous/tumor/'

# %%
end_url = '/cgcc/jhu-usc.edu/humanmethylation450/methylation/'

# %% [markdown]
# <b>Cancer Subtypes</b>

# %% [markdown]
# * Comment below indicates cancers that were removed due to illegitimate file structure on TCGA website

# %%
cancertype = ['acc','blca','brca','cesc','chol','coad','dlbc','esca','hnsc','kich','kirc',
              'kirp','lihc','luad','lusc','meso','ov','paad','pcpg','prad',
              'read','sarc','skcm','stad','tgct','thca','thym','ucec','ucs','uvm']
#types removed: cancertypes = ['laml','gbm','lgg','misc']

# %%
urls = []
for i in cancertype:
    url = base_url + i + end_url
    urls.append(url)

f=open('url_list.txt','w')
l1=map(lambda x:x+'\n', urls)
f.writelines(l1)
f.close()

# %% [markdown]
# <b>Use Certificate to Aunthenticate User Acess to TCGA HTTP directory data</b>

# %%
# !xargs curl --cacert $PATH_TO_CERT -I < url_list.txt
clear_output()

# %% [markdown]
# <b>Beautiful Soup module is used to parse links from webpage </b>

# %% [markdown]
# * Creates list of TCGA cancer methylation data urls by parsing urls for tar archives for data and patient mapping respectively

# %%
urls = []
tar_links = []

for i in cancertype:
    print i
    try:
        url = base_url + i + end_url
        urls.append(url)      
        webpage = urllib2.urlopen(url)
        soup = BeautifulSoup(webpage.read(), 'html.parser')
        
        links = [url + link.get('href') for link in soup.find_all('a') 
                                      if (link.get('href') != None )
                                      and 'tar.gz' in link.get('href')
                                      and '_2.' not in link.get('href')
                                      and '_3.' not in link.get('href')
                                      and '.md5' not in link.get('href')]
        
        aux_links = [url + link.get('href') for link in soup.find_all('a') 
                                      if (link.get('href') != None )
                                      and 'aux' in link.get('href')
                                      and '_2.' not in link.get('href')
                                      and '_3.' not in link.get('href')
                                      and '.md5' not in link.get('href')
                                      and 'tar.gz' in link.get('href')]
    
        tar_links.extend(links)
        tar_links.extend(aux_links)
    except urllib2.HTTPError:
        print '{} failed'.format(i)
# Out:
# acc
# blca
# brca
# cesc
# chol
# coad
# dlbc
# esca
# hnsc
# kich
# kirc
# kirp
# lihc
# luad
# lusc
# meso
# ov
# paad
# pcpg
# prad
# read
# sarc
# skcm
# stad
# tgct
# thca
# thym
# ucec
# ucs
# uvm

# %% [markdown]
# * Write downloaded links to list

# %%
f=open('tar_links.txt','w')
l1=map(lambda x:x+'\n', tar_links)
f.writelines(l1)
f.close()

# %% [markdown]
# <b>Download tar.gz files from list extracted</b>

# %%
# !wget -q -i tar_links.txt

# %% [markdown]
# <b>Unzip, Extract, rearrange and count files using bash script </b>
# * First, tar.gz files are unzipped and extracted
# * Excess tar files are removed
# * Pertinent files are then moved to corresponding folders and each folder is counted for the number of idat files present

# %%
# %%bash
# #!/bin/bash
# for i in *tar.gz; do  tar -xkizf $i; done
# Out:
# tar: Skipping to next header
# tar: jhu-usc.edu_ACC.HumanMethylation450.aux.1.0.0/ACC.processing.log.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_ACC.HumanMethylation450.mage-tab.1.0.0/DESCRIPTION.txt: Cannot open: File exists
# tar: jhu-usc.edu_ACC.HumanMethylation450.mage-tab.1.0.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_ACC.HumanMethylation450.mage-tab.1.0.0/jhu-usc.edu_ACC.HumanMethylation450.1.0.0.idf.txt: Cannot open: File exists
# tar: jhu-usc.edu_ACC.HumanMethylation450.mage-tab.1.0.0/jhu-usc.edu_ACC.HumanMethylation450.1.0.0.sdrf.txt: Cannot open: File exists
# tar: jhu-usc.edu_ACC.HumanMethylation450.mage-tab.1.0.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.10.0/BLCA.processing.log.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.11.0/BLCA.processing.log.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.11.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.11.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.2.0/BLCA.processing.log.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.2.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.2.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.7.0/BLCA.processing.log.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.8.0/BLCA.processing.log.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.8.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.9.0/BLCA.processing.log.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.aux.1.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655052_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R03C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R03C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R05C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R05C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R06C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R06C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/6164655053_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.0.0/MANIFEST.txt: Cannot open: File exists
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R05C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R05C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R06C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R06C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915031_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915032_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915032_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915032_R02C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7786915032_R02C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7796806006_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/7796806006_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.10.0/MANIFEST.txt: Cannot open: File exists
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R05C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R05C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R06C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R06C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915031_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915032_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915032_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915032_R02C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7786915032_R02C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7796806006_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/7796806006_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.11.0/MANIFEST.txt: Cannot open: File exists
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.12.0/7786915031_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.12.0/7786915031_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.12.0/7786915031_R02C02_Grn.idat: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R05C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R05C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R06C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R06C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915031_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915032_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915032_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915032_R02C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7786915032_R02C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7796806006_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/7796806006_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.13.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R05C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R05C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R06C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R06C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915031_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915032_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915032_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915032_R02C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7786915032_R02C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7796806006_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/7796806006_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.10.14.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.10.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655052_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R02C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R02C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R03C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R03C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R05C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R05C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R06C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R06C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/6164655053_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/MANIFEST.txt: Cannot open: File exists
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.1.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.11.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R04C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R04C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R05C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R05C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R06C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655052_R06C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R01C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R01C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R01C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R01C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R02C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R02C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R02C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R02C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R03C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R03C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R03C02_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R03C02_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R04C01_Grn.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R04C01_Red.idat: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/6164655053_R04C02_Grn.idat: Cannot open: File exists
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.2.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.10.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.11.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.7.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.8.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.12.9.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.3.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.3.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.13.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.13.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.13.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.4.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.4.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.5.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.5.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.15.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.6.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.6.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.6.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.16.11.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.16.11.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.7.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.7.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.8.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.8.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.9.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.1.9.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.2.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.2.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.6.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.3.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.6.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.4.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.6.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.6.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.6.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.7.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.10.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.10.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.11.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.11.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.3.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.4.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.5.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.6.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.6.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.7.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.7.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.8.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.8.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.9.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_BLCA.HumanMethylation450.Level_1.8.9.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# ...
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.13.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.13.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.13.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.13.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.13.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.1.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.14.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.14.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.14.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.14.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.14.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.1.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.15.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.15.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.15.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.15.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.15.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.1.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.1.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.2.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.3.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.4.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.16.5.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.1.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.1.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.2.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.2.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.3.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.3.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.4.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.4.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.5.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.2.5.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.3.0.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.4.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.4.2.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.4.3.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.4.4.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.4.5.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.2.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.3.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.4.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.5.5.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.0.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.0.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.6.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.1.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.2.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.3.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.4.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.7.5.0/README_DCC.txt: Cannot open: File exists
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.1.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.1.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.1.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.2.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.2.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.2.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.3.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.3.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.3.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.4.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.4.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.4.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.5.0/CHANGES_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.5.0/README_DCC.txt: Cannot open: File exists
# tar: jhu-usc.edu_UCEC.HumanMethylation450.Level_1.9.5.0/MANIFEST.txt: Cannot open: File exists
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors
# tar: Skipping to next header
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors

# %%
# %%bash
# #!/bin/bash
# find . -type f -name '*tar.gz' -exec rm {} +
# find . -type f -name '*tar.gz.1' -exec rm {} +

# %% [markdown]
# <b>List out folder directory</b>

# %%
folders = !ls -d jhu-usc.edu*

# %% [markdown]
# <b>Pull out unique list of cancers</b>

# %%
pull_cancer = lambda f: f.split('_')[1].split('.')[0]
cancers = {pull_cancer(f) for f in folders}

# %% [markdown]
# <b>Move files into cancer level directory</b>

# %%
for cancer in cancers:
    sub_f = [f for f in folders if pull_cancer(f) == cancer]
    # !mkdir $cancer
    for f in sub_f:
        # !cp $f/* $cancer
