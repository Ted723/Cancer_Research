# %% [markdown]
# # Integrative and Comparative Genomic Analysis of Lung Squamous Cell Carcinomas in East Asian Patients

# %% [markdown]
# * Need more summary and accession codes

# %% [markdown]
# ### Patient Analysis

# %% [markdown]
# * WES: 104 Lung Squamous Cell Carcinoma
# * RNASeq: 26 LSCC
# * Copy#/SNP: 82 LSCC
# * All East Asian Patients

# %% [markdown]
# ### Mutation Analysis

# %% [markdown]
# * <b>SMGs:</b> TP53, RB1, PTEN, NFE2L2, KEAP1, MLL2

# %% [markdown]
# ### Summary

# %% [markdown]
# ### Accession Codes

# %% [markdown]
# ## Data Analysis

# %%
cd ~

# %%
# %pylab inline
import pandas as pd
import seaborn as sns

# %%
PATH = 'Documents/IdekerLab/CancerPapers/Integrative and Comparative Genomic Analysis of Lung Squamous Cell Carcinomas in East Asian Patients/'
MUT_PATH = 'Documents/IdekerLab/CancerPapers/Pat-Mut_Data/'
MERGED_PATH = 'Documents/IdekerLab/CancerPapers/Merged/'

# %% [markdown]
# ## Hard Data

# %% [markdown]
# * No common denom
# * Very little data provided

# %% [markdown]
# ### Patient Data

# %%
patchar = pd.read_csv(PATH + 'patchar.csv', index_col=0)
patchar
# Out:
#           Sample ID. Gender  Age Organ Specifed site (organ)  \
# Histology
# Squamous         J10      M   64  Lung                   LUL
# Squamous         J32      M   86  Lung                   LLL
# Squamous         J33      M   77  Lung                   RLL
# Squamous         J11      M   71  Lung                   RUL
# Squamous         J46      M   63  Lung                   RUL
# Squamous         J76      M   77  Lung                   RML
# Squamous         J52      M   69  Lung                   LUL
# Squamous         J54      M   78  Lung                   LUL
# Squamous         J65      M   76  Lung                   RLL
# Squamous         J90      M   79  Lung                   RLL
# Squamous         J83      M   75  Lung                   RUL
# Squamous         J38      M   62  Lung                   LLL
# Squamous         J57      M   77  Lung                   RLL
# Squamous         J63      M   58  Lung                   LLL
# ...

# %% [markdown]
# ### Mutation Data

# %% [markdown]
# ### Merged Data
