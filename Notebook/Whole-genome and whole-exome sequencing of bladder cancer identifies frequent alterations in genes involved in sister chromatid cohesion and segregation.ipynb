# %%
# %pylab inline
import pandas as pd
import seaborn as sns
PATH = '/cellar/users/talejand/Documents/IdekerLab/CancerPapers/WGS and WES of bladder cancer/'
MUT_PATH='/cellar/users/talejand/Documents/IdekerLab/CancerPapers/Pat-Mut_Data/'
MERGED_PATH = '/cellar/users/talejand/Documents/IdekerLab/CancerPapers/Merged/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Whole-genome and whole-exome sequencing of bladder cancer identifies frequent alterations in genes involved in sister chromatid cohesion and segregation

# %% [markdown]
# ## TCC (transitional cell carcinoma), most prominent of Bladder Cancers

# %% [markdown]
# <b>Bladder Cancer</b>: Heterogeneous Disease w/ 2 Subtypes
#
# 1. Superficial
#
# 2. Invasive

# %% [markdown]
# <b>WGS/WES:</b> 99 patients

# %% [markdown]
# <b>Determinations</b>:
#
# * Confirmed recurring mutations and identified additional altered genes/pathways
#
#
# * <b>Frequent Alterations</b>: STAG2 and ESPL1
#
#      * genes involved in sister chromatic cohesion and segregation (SCCS)
#
#
#
# * <b>Recurrent Fusion:</b> FGFR3 and TACC3
#      * detected by transcriptome seq of 42 DNA seq tumors
#
#
# * 32% (32/99) of tumors had genetic alterations in the SCSSS process
#
# * Analysis provides evidence that these type of alterations may be involved in bladder tumorigenesis

# %% [markdown]
# <b>Somatic Mutations</b> (candidate): 11,240
#
# validation experiments on 1,119 predicted somatic substitutions and 91 indels confirmed 1,023 (91%) and 67 (74%), respectively, by Sanger sequencing
#
# * WGS detected CNAs and obtained fourfold mean haploid coverage for each sample
#
# * RNA-seq on a subset of 42 DNA-sequenced tumors, including 16 for which matched, morpho- logically normal bladder tissue was available

# %% [markdown]
# <b>Significantly Mutated Genes</b> <i>(SMGs)</i>: 37
#
# * TP53, HRAS, FGFR3, PIK3CA, RB1, KRAS, and TSCI
# * 8 chromatin Remodeling Genes: UTX, ARID1A, MLL-MLL3, CREBBP- EP300, NCOR1 and CHD6
# * 13 prev. unreported, most important STAG2 (11%?), then ERCC2, TRRAP and FAT4
#     * 9/11 mutations were truncating ( 3 small frameshift indels, 4 nonsense, 2 splice-site)
#     * STAG2 Genomic Deletions in 5/99 tumors
#         * By screening all exons of STAG2 in an additional 50 tumor-normal pairs form individuals with TCC by Sanger sequencing, we iden- tified 5 somatic mutations in 4 tumors
#         * We also examined the methylation status of the STAG2 promoter in 30 TCCs by bisulfite sequencing and found STAG2 promoter hyper- methylation in 7 tumors (23%) relative to matched normal samples

# %% [markdown]
# <b>Individuals w/ STAG2 somatic alt. have sig. worse prognosis</b>
#     * suggests STAG2 is an independent predictor of worse outcomes in TCC

# %% [markdown]
# <b>Frequent mutations in multiple tumors</b> <i>in other chromatin- remodeling genes</i>, including:
# * the histone demethylase genes KDM6A(UTX) and UTY (30%), the chromatin-remodeler genes ARID1A and ARID4A (17%), the histone lysine methyltransferase genes KMT2A (MLL), KMT2C (MLL3) and KMT2E (MLL5) (16%), the histone acetyltransferase genes EP300 and EP400 (15%), the SWI/SNF complex–related genes SMARCA4 and SMARAC1 (7%) and the his- tone demethylase genes KDM5A (JARID1A) and KDM5B (JARID1B) (6%).
#
# * Total: 57 of the 99 cases (58%) harbored somaticmutations in chromatin-remodeling genes, further indicating that altered epigenetic regulation of chromatin and chromatin post- translational modifications may be a major driver mechanism in TCC3.

# %% [markdown]
# <b>Evaluation of aneuploidy:</b>
#
# * quantifying the extent of copy number changes on chromosome arms and found that tumors with genetic alterations in STAG2 had more aneuploidy (P = 0.01) than tumors with wild- type SCCS genes (Supplementary Fig. 7), which is consistent with a published study10.
#
# * In contrast with the observation in solid tumors, many STAG2-mutated primary leukemias have completely normal karyotypes11,12.
#
# * These contradictory observations in different types of cancer suggest that further comprehensive investigation of STAG2

# %% [markdown]
# <b>Profiling of 99 tumors for CNAs useing WGS</b>
#
# * abnormalities:
#     1. Gain: 5p, 8q, 13p, 20p, 20q
#     2. Loss: 8p, 9p, 11p, 14p, 15p, 17p, and 21p

# %% [markdown]
# ### Other

# %% [markdown]
# applied GSITIC14 analysis to whole-genome sequencing data to identify recurrent focal CNAs, and this analysis yielded 84 regions of focal amplification (Supplementary Fig. 12 and Supplementary Table 9), several of which included CNAs previously detected in bladder cancer13, which encompassed genes such as TRIO, MDM2, MYC, E2F3, CCND1 and ERBB2

# %% [markdown]
# amplifications defined regions of CNAs reported for the first time, to our knowledge, in bladder cancer, including CCNE1, CEBPA, E2F1 and MUC1

# %% [markdown]
# An interesting finding was frequent amplification of DHFR, encoding dihydrofolate reductase, which is a target of many anticancer agents15, at 5q (frequently loss in our cohort) in 14 tumors (14%) (Supplementary Figs. 16 and 17 and Supplementary Note).
#
# identified 80 recurrent focal deletion regions, including RB1 and CREBBP, which were also fre- quently truncated in TCCs.
#
# One of the most common focal deletions, detected in 50 tumors (50%), was a deleted region at 9p21 containing CDKN2A and CDKN2B (Supplementary Fig. 18) and is a widely reported genomic alteration in bladder cancer16.

# %% [markdown]
# <b>Notable</b>
#
# * Highly frequent genomic alterations in genes involved in the SCCS process, including:
#     * alterations in STAG2, ESPL1 and NIPBL, and a recurrent FGFR3-TACC3 fusion in TCC.
#     * In contrast to other cancers in which only rare or low-frequency alterations in SCCS genes have been observed10,22,23, bladder can- cer is the first type of cancer, to our knowledge, with predominant genetic lesions in genes involved in the SCCS process.
#
# * Although we do not yet understand the detailed mechanisms by which STAG2 may contribute to TCC pathogenesis, the discovery of highly recur- rent alterations in the genes involved in the SCCS process in TCC identifies yet another pathway that is undoubtedly relevant for TCC. Our analysis suggests the necessity of comprehensive investigation of SCCS genes to elucidate their exact roles in causing aneuploidy or bladder tumorigenesis.

# %% [markdown]
# <b>Mutations</b>
#
#     * Mutated Genes: 6,737
#     * Mutations in Genes: 11,240
#         * Synonymous in coding Sequences: 3,009
#         * Splice Site: 192
#         * Non-synonymous in coding sequences:
#             1. Missense: 6,839
#             2. Nonsense: 632
#             3. Insertions: 170
#             4. Deletions: 398

# %% [markdown]
# ## Hard Data

# %% [markdown]
# ### Patient Data:

# %%
#Patient Data

#read in csv 
patdata = pd.read_csv(PATH + 'clinicaldata.csv')
#Drop unwanted columns
patdata.drop(['Superficial/Invasive','RNA-Seq'], 1, inplace=True)
#rename columns to format
patdata.rename(columns={'TNM':'Tumor_ID','Primary/Relapsed': 'Status','Case_ID':'Patient_ID','Sex':'Gender'}, inplace=True)

patdata['Patient_ID']=patdata['Patient_ID'].map(str.strip)
#write to csv in PatMut folder
patdata.to_csv(MUT_PATH+'patcharWGSWESbladder.csv')

patdata
#.query('Patient_ID == "B80-1"')
# Out:
#    Patient_ID Gender  Age  Tumor_ID  Grade     Status   WES   WGS
# 0         B10     M    52   T2N0M0       2   Primary   Yes   Yes
# 1        B100     M    25   T1N0M0       1   Primary   Yes   Yes
# 2        B101     F    69   T1N0M0       1   Primary   Yes   Yes
# 3        B102     M    45   T1N0M0       1   Primary   Yes   Yes
# 4        B103     M    54   T1N0M0       1   Primary   Yes   Yes
# 5        B104     M    52   T2N0M0       1   Primary   Yes   Yes
# 6      B104-0     M    72   T1N0M0       1   Primary   Yes   Yes
# 7        B105     M    62   T2NxMx       1  Relapsed   Yes   Yes
# 8      B105-0     M    60   T2NxMx       1   Primary   Yes   Yes
# 9      B105-1     M    64   T2NxMx       2   Primary   Yes   Yes
# 10       B106     M    56   T2NxMx       1   Primary   Yes   Yes
# 11       B107     M    68   T2NxMx       3   Primary   Yes   Yes
# 12       B109     M    46   T1N0M0       1  Relapsed   Yes   Yes
# ...

# %% [markdown]
# ### Mutation Data:

# %%
# Mutation Data

#to get the chromosome from genome change.. how?
## can I take the characters in each string between chr and : and strip it out to a new chr column????


#read in csv
mut = pd.read_csv(PATH + 'ng.2798-S3.csv')
#drop unwanted columns
mut.drop(['Codon change','Nucleotide (cDNA)$','Amino Acid'], 1, inplace=True)
#rename columns to format
mut.rename(columns={'Gene Symbol':'Gene','Tumor ID':'Patient_ID','Nucleotide (genomic)#':'Genome_Change','Mutation Type':'Mutation_Type'}, inplace=True)

mut['Patient_ID'] = mut['Patient_ID'].map(str.strip)
#write to csv in Mutdata folder
mut.to_csv(MUT_PATH+ 'mutdataWGSWESbladder.csv')
mut
# Out:
#           Gene Patient_ID         Genome_Change Protein_Change  \
# 0        ABCA8        B65   g.chr17:64393053T>A              -
# 1       ACAD10      B81-1  g.chr12:110624480A>T        p.R107*
# 2        ACAT2      B85-0   g.chr6:160119679A>T              -
# 3        ACIN1     B105-0   g.chr14:22617904C>T        p.E716K
# 4        ACIN1        B22   g.chr14:22618068G>A        p.S661F
# 5        ACIN1        B45   g.chr14:22603490G>A        p.Q844*
# 6        ACIN1        B52   g.chr14:22634096C>T         p.L80L
# 7        ACIN1     B80-13   g.chr14:22602557C>T        p.E947K
# 8         ACTB       B101     g.chr7:5534867C>T        p.E125K
# 9         ACTB     B105-0     g.chr7:5534806G>A        p.S145F
# 10        ACTB      B59-3     g.chr7:5534768C>T        p.G158R
# 11        ACTB        B64     g.chr7:5533990G>A        p.S348L
# 12       ACTG1       B101   g.chr17:77093710C>T         p.Q59Q
# 13    ADAMTSL3         B5   g.chr15:82491167C>G       p.S1578C
# ...

# %% [markdown]
# ## Merged Data:

# %%
#I had originally merged to the outer, but there were ten more rows than genes.. therefore i merged to right which
#is on mut data and it has now same number... need to figure out merging better..
merged = pd.merge(patdata, mut, how='right')

merged['Tissue'] = 'Bladder cancer - transitional cell carcinoma'

merged.to_csv(MERGED_PATH+'mergedWGSWESbladder.csv')

merged
# Out:
#      Patient_ID Gender  Age Tumor_ID  Grade     Status   WES   WGS     Gene  \
# 0          B101     F    69  T1N0M0       1   Primary   Yes   Yes      ACTB
# 1          B101     F    69  T1N0M0       1   Primary   Yes   Yes     ACTG1
# 2          B101     F    69  T1N0M0       1   Primary   Yes   Yes    ATP2A3
# 3          B101     F    69  T1N0M0       1   Primary   Yes   Yes     FRRS1
# 4          B101     F    69  T1N0M0       1   Primary   Yes   Yes     HUWE1
# 5          B101     F    69  T1N0M0       1   Primary   Yes   Yes      MLL5
# 6          B101     F    69  T1N0M0       1   Primary   Yes   Yes       NF1
# 7          B101     F    69  T1N0M0       1   Primary   Yes   Yes       NF1
# 8          B101     F    69  T1N0M0       1   Primary   Yes   Yes       NHS
# 9          B101     F    69  T1N0M0       1   Primary   Yes   Yes     SALL4
# 10         B101     F    69  T1N0M0       1   Primary   Yes   Yes    SFRS16
# ...

# %% [markdown]
# ### Copy Number Data:

# %% [markdown]
# ### Other Data:

# %%
sigmutgene = pd.read_csv(PATH + 'sigmutgenese.csv', index_col = 0)
sigmutgene.ix[['STAG2 ']]

# c=b.query('Gender != ["M"]').dropna(subset=['Gender'])
# d=c.sort('Age', ascending=False)
# d.sort('Site').query('Site != ["Small intestine","Lymph node"]')
# Out:
#         Missense  Nonsense,splice_site,or_indel  Synnonymous_mutations  \
# STAG2          2                              9                      0
#
#         Total_Mutations N:S_Ratio  \
# STAG2                11        -
#
#         Number(%)_of_subjects_harboring_non-silent_mutations       P-Value
# STAG2                                                  11     3.830000e-14

# %%
#STAG2 mutations detected  in discovery(99) and prevalence(50) cohorts

stag2muts = pd.read_csv(PATH + 'stag2muts.csv', index_col = 0)
stag2muts.drop(['Nucleotide(cDNA)','Codon_Change','Amino_Acid_Change'], 1, inplace=True)
stag2muts
# Out:
#        Tumor_ID                     Genome_Change Protein_Change  \
# Gene
# STAG2     B105               g.chrX:123048109C>T       p.Q1029*
# STAG2     B109               g.chrX:123037893T>C        p.I855T
# STAG2     B114               g.chrX:123027705G>A              -
# STAG2      B18               g.chrX:123045061C>T       p.R1012*
# STAG2      B35               g.chrX:123012651G>A              -
# STAG2      B57               g.chrX:122999075G>A        p.W102*
# STAG2    B80-3               g.chrX:123024692C>T        p.Q593*
# STAG2    B89-4               g.chrX:123011737G>T        p.R305L
# STAG2     B110    g.chrX:123030112_123030112delA         L761fs
# STAG2      B87              g.chrX:123006776insA         L182fs
# STAG2   B89-16   g.chrX:123024495_123024496delTG         F567fs
# STAG2       267              g.chrX:123006731C>T        p.Q167*
# STAG2       267              g.chrX:123006861C>G        p.S210*
# ...

# %%
# Not needed: Significantly Mutated Paths

sigmutpaths = pd.read_csv(PATH + 'sigmutpaths.csv', index_col = 0)
sigmutpaths
# Out:
#                                   #_of_reference_genes_in_category  \
# Pathway
# MAPK signaling pathway                                         269
# Cell cycle                                                     128
# ErbB signaling pathway                                          87
# ECM-receptor interaction                                        84
# Calcium signaling pathway                                      178
# egulation of actin cytoskeleton                                216
# Insulin signaling pathway                                      137
# eurotrophin signaling pathway                                  126
# Long-term potentiation                                          70
# Axon guidance                                                  129
# Notch signaling pathway                                         47
# GnRH signaling pathway                                         101
# TGF-beta signaling pathway                                      87
# ...

# %%
# %pylab inline
patdata['Age'] = np.arange(99)
patdata['Diagnosis'] = patdata.Age == 3
patdata.Diagnosis.value_counts()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# False    98
# True      1
# dtype: int64

# %%
patdata['Man'] = patdata['Gender'] == 'M '
patdata['Gender'] = patdata['Gender'].map(str.strip)
patdata['Man fo real'] = patdata['Gender'] == 'M'
patdata.query('Gender == "M"')
a = patdata.head()
#a
del a['Man']
'Gender' in a.columns
'Gender' in a.index
b = a.set_index('Status')
#a.drop(['Tumor_ID','WES'], axis =1)
b < 5
# Out:
#          Patient_ID Gender   Age Tumor_ID Grade    WES    WGS Diagnosis  \
# Status
# Primary       False  False  True    False  True  False  False      True
# Primary       False  False  True    False  True  False  False      True
# Primary       False  False  True    False  True  False  False      True
# Primary       False  False  True    False  True  False  False      True
# Primary       False  False  True    False  True  False  False      True
#
#          Status is now Good Status is now bad Man fo real
# Status
# Primary                True              True        True
# Primary                True              True        True
# Primary                True              True        True
# Primary                True              True        True
# Primary                True              True        True
