# %% [markdown]
# # CANT MERGE PAT AND MUT DATA BECAUSE NO COMMON DENOMINATOR

# %% [markdown]
# ## Also, why don't people sequence a single person (or group of people) genome in periodic phases of their life to seee what is changed, and if they have developed cancer, then couldnt we see what changed to make them develop cancer?

# %%
# %pylab inline
import pandas as pd
PATH = '/cellar/users/talejand/Documents/IdekerLab/CancerPapers/ES_identifies_frequent_inactivating_mutations_in_BAP1,ARID1A,and_PBRM1_in_intrahepatic_cholangiocarcinoma_/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Exome Sequencing Identifies Frequent Inactivating Mutations in BAP1, ARID1A and PBRM1 in Intrahepatic Cholangiocarcinomas

# %% [markdown]
# ## Through exomic sequencing of 32 intrahepatic
# cholangiocarcinomas, we discovered frequent inactivating
# mutations in multiple chromatin-remodeling genes (including
# BAP1, ARID1A and PBRM1), and mutation in one of these
# genes occurred in almost half of the carcinomas sequenced.
# We also identified frequent mutations at previously reported
# hotspots in the IDH1 and IDH2 genes encoding metabolic
# enzymes in intrahepatic cholangiocarcinomas. In contrast,
# TP53 was the most frequently altered gene in a series of nine
# gallbladder carcinomas. These discoveries highlight the key
# role of dysregulated chromatin remodeling in intrahepatic
# cholangiocarcinomas.

# %% [markdown]
# # # of Patients: 32 intrahepatic cholangiocarcinomas & 9 gallbladder carcinoma
#
#  * No subjects had known risk factors for development of this cancer
#  * Both gallbladder and intraheptic arise from biliary tree, although suggested different underlying tumor biology
#  * subset of individuals have identifiable risk factors, BUT MAJORITY DO NOT

# %% [markdown]
# Somatic Muations: 1,259 in 1,128 in the 32 intrahepatic cholangiocarcinomas
#
# * mean of 39 somatic mutations per sample, range of 13-300
#
# * All samples (less 1) contained less than 60 nonsyn som mut
#
# * 2 - TP53 (6%)
# * 1 - CDK2NA (inactivating)
# * 1 - KRAS (oncogenic hotspot mut.)
# * 1 - NRAS
# * 1 - TGFBR2
# * 0 - SMAD4 (DPC4)

# %% [markdown]
# Somatic Mutations in Gallbladder Carcinomas:
#
# * 1/9 gallbladder carcinomas contained ~3,000 nonsyn somatic mutations
#     * This phenotype was unusual and omitted
# * 8/9 contained 724 som mut in 695 genes
# * Average: 91 som mut/ sample; range 42-252

# %% [markdown]
# Frequent mutations: IDH1(4/32) and IDH2(2/32) (reported hotspots)(19% total)

# %% [markdown]
# Frequent inactivating mutations: BAP1, ARID1A, and PBRM1
#
# 1. BAP1: occured in 8/32 (25%)
#
# 2. ARID1A: 6/32 (19%)
#
# 3. PBRM1: 5/32 (17%)
#
#
# * At least 1 chromatin remodeling gene altered in 15/32 (47%)

# %% [markdown]
# Also mutation in FGR2 (4/32) (13%)

# %% [markdown]
# When considered together, subjects with a mutation in any one of the three chromatin-remodeling genes (BAP1, ARID1A or PBRM1) trended toward worse survival compared to subjects in whom all three genes were wild type (3-year survival of 47.1% for subjects with mutations compared to 93.3% for subjects without mutations), but these results were not statistically significant (P = 0.1672 by log-rank test).

# %% [markdown]
# <figure>
#
#
# 							<figcaption><span class="legend">
# 					Table 1: Genes with frequent somatic alterations in intrahepatic cholangiocarcinoma				</span></figcaption>
#
#
#
#
# 			<div class="item-content box">
#
# 															<div class="table-wrapper">															<table class="data">
# 																																																<colgroup><col><col><col><col><col><col><col><col><col></colgroup><thead><tr><th class="last rowsep">Gene</th><th class="last rowsep">Number of mutations (DS) (%)</th><th class="last rowsep">Types of mutations (DS)<sup><a href="#t1-fn2">a</a></sup></th><th class="last rowsep"><i>P</i> value (DS)<sup><a href="#t1-fn3">b</a></sup></th><th class="last rowsep">Number of mutations (PS) (%)</th><th class="last rowsep">Types of mutations (PS)<sup><a href="#t1-fn2">a</a></sup></th><th class="last rowsep">Mutant 3-year survival (%)<sup><a href="#t1-fn4">c</a></sup></th><th class="last rowsep">Wild-type 3-year survival (%)<sup><a href="#t1-fn4">c</a></sup></th><th class="last rowsep"><i>P</i> value for 3-year survival<sup><a href="#t1-fn4">c</a></sup></th></tr></thead>
# 																																																																											<tfoot><tr><td colspan="9"><div id="t1-fn1" class="footnote"><p>DS, discovery screen; PS, prevalence screen.</p></div></td></tr><tr><td colspan="9"><div id="t1-fn2" class="footnote"><p><sup>a</sup>FS, frameshift insertion-deletion; IF, in-frame insertion-deletion; SS, splice-site mutation; MS, missense mutation; NS, nonsense mutation.</p></div></td></tr><tr><td colspan="9"><div id="t1-fn3" class="footnote"><p><sup>b</sup>Calculated using Bonferroni correction for multiple comparisons (see <a href="/ng/journal/v45/n12/full/ng.2813.html#supplementary-information">Supplementary Table 6a</a> for additional data).</p></div></td></tr><tr><td colspan="9" class="last"><div id="t1-fn4" class="footnote"><p><sup>c</sup>Calculated using clinical data from discovery screen samples.</p></div></td></tr></tfoot>
# 																																																																			<tbody>																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																															<tr class="alt"><td class="first-cell"><i>BAP1</i></td><td>8 (25)</td><td>3 FS, 1 IF, 2 SS, 2 MS</td><td>7.4 × 10<sup>−12</sup></td><td>5 (16)</td><td>1 SS, 4 MS</td><td>27</td><td>81</td><td>0.102</td></tr>
# 																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																<tr><td class="first-cell"><i>ARID1A</i></td><td>6 (19)</td><td>3 NS, 1 FS, 2 MS</td><td>4.3 × 10<sup>−3</sup></td><td>3 (9)</td><td>1 NS, 1 FS, 1 MS</td><td>40</td><td>79</td><td>0.51</td></tr>
# 																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																														<tr class="alt"><td class="first-cell"><i>PBRM1</i></td><td>5 (17)</td><td>1 NS, 4 FS</td><td>1.8 × 10<sup>−5</sup></td><td>3 (9)</td><td>1 NS, 1 FS, 1 MS</td><td>50</td><td>76</td><td>0.75</td></tr>
# 																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																													<tr><td class="first-cell"><i>IDH1</i> or <i>IDH2</i></td><td>6 (19)</td><td>6 MS</td><td>5.4 × 10<sup>−3</sup></td><td>7 (22)</td><td>7 MS</td><td>33</td><td>81</td><td>0.0034</td></tr>
# 																																											</tbody>							</table>
# 											</div>
# 																				</div>
#
#
#
#
# 			<nav>				<ul class="figure-nav">
# 										<li class="index only"><a href="/ng/journal/v45/n12/fig_tab/ng.2813_ft.html">Figures/tables index</a></li>
# 									</ul>
# 			</nav>
#
#
# 					</figure>

# %% [markdown]
# # Genes with Frequent Inactivating Mutations in Intrahepatic Cholangiocarcinoma

# %% [markdown]
# <img class="decoded shrinkToFit" alt="http://www.nature.com/ng/journal/v45/n12/images/ng.2813-F1.jpg" src="http://www.nature.com/ng/journal/v45/n12/images/ng.2813-F1.jpg" height="282" width="605">

# %% [markdown]
# # Tissue: Intrahepatic Cholangiocarcinomas

# %% [markdown]
# Somatic mutations components of the PI3K pathway (22% of cholangiocarcinomas in total)
#
# * 2 - PIK3CA
# * 2 - PTEN
# * 2 - PIK3C2G
# * 1 - PIK3C2A

# %% [markdown]
# # Discoveries highlight key role of: Dysregulated Chromatin Remodeling in Intrahepatic Cholangiocarcinomas

# %% [markdown]
# ### Point is: Accurately determine mutation frequency of genes

# %% [markdown]
# Prevalence Screen (independent set of 32 intrahepatic cholangiocarcinoma samples)
#
# * Sequenced subset of potential driver genes in:
#
#     * AKT1, ARID1A, BAP1, CDKN2A, CTNNB1, IDH1, IDH2, KRAS, NRAS, PBRM1, PIK3C2A, PIK3C2G, PIK3CA, PTEN, SMAD4, TGFBR2 and TP53

# %% [markdown]
#  As was observed in the discovery screen:
#
# * multiple mutations were identified in chromatin-remodeling genes:
#
#     * BAP1 was mutated in 5 of 32 cholangiocarcinomas (16%),
#     * ARID1A was mutated in 3 of 32 cholangiocarcinomas (9%), and
#     * PBRM1 was mutated in 3 of 32 cholangiocarcinomas (9%) (Table 1 and Supplementary Table 7a).
#
# * In the prevalence screen, mutations in these genes were mutually exclusive, and mutation in one of these genes occurred in 11 of 32 cholangiocarcinomas (34%).
#
# * Combining the discovery and prevalence screens, BAP1 was mutated in 13 of 64 tumors (20%), ARID1A was mutated in 9 of 64 tumors (14%), and PBRM1 was mutated in 8 of 64 tumors (13%), adding up to 26 cholangiocarcinomas with mutations in chromatin-remodeling genes out of 64 total cholangiocarcinomas (41%).
#
# * Frequent mutations in IDH1 and IDH2 hotspots were also identified in this prevalence screen, as mutations in these genes were identified in 7 of 32 cholangiocarcinomas (22%; overall prevalence of 20% when both the discovery and prevalence screens were combined).
#
# * The prevalence screen identified additional mutations in KRAS, NRAS and components of the PI3K pathway (PIK3CA and PI3KC2G), confirming the key role of RAS and PI3K signaling in this tumor type.

# %% [markdown]
# Overall, these data on somatic mutations in intrahepatic cholangiocarcinomas highlight the genetic heterogeneity of the disease. No single gene was mutated in >25% of the tumors sequenced. However, even considering this intertumoral genetic heterogeneity, several pathways were frequently targeted—for example, genes involved in chromatin remodeling (including BAP1, ARID1A and PBRM1) were somatically altered in almost half of the intrahepatic cholangiocarcinomas analyzed.

# %% [markdown]
# # Gallbladder Carcinoma

# %% [markdown]
# ## Most Freq. Mut. Gene: TP53 (5/8) (63%) (w/out mutator phenotype)

# %% [markdown]
# Somatic Mutations (out of 8 tumors) ??
#
#     1. TP53 63% (only  mutation w. p < 0.05 bonferroni)
#     2. PBRM1 25%
#     3. KMT2C / MLL3 (25%) (chromatin remodeling gene, crg)
#         * no mutations in this gene in cholangiocarcinomas
#     4. PIK3CA (1 mut.)
#     5. SMAD4 (1 mut.)
#     6. No Mutations: BAP1, ARID1A, IDH1, IDH2

# %% [markdown]
# To estimate the frequency of somatic mutations in potential driver genes more accurately, we sequenced the same subset of potential driver genes in an independent set of eight additional gallbladder carcinomas (prevalence screen).
#
#     1. PBRM1 (2 additional muts) (25%)
#     2. BAP1 (13%)
#     3. ARID1A (13%) (Supplementary Table 7b).
#     `

# %% [markdown]
# Combine Discovery/Prevalence Screens for Galbladder Carcinoma
#
# * Mutation Prevalence
#
#     1. BAP1 (6%)
#     2. ARID1A (6%)
#     3. PBRM1 (25%)
#
# * No mutations in IDH1 or IDH2 in the eight additional gallbladder carcinomas analyzed.
#
# * In addition, the prevalence screen confirmed the key role of TP53 mutations in gallbladder carcinoma, with mutations identified in two of eight tumors (25%; overall prevalence of 44% when both the discovery and prevalence screens were combined).

# %% [markdown]
# # The number of gallbladder carcinomas analyzed in the current study is too small to make definitive conclusions about the genetic relationships between gallbladder carcinoma and intrahepatic cholangiocarcinoma.

# %% [markdown]
# # These data highlight the key role of mutations in chromatin-remodeling genes in cholangiocarcinoma: frequent inactivating mutations occur in three different genes, affecting almost half of the tumors sequenced.

# %% [markdown]
# Accession codes.
# Raw sequencing data, which include germline information, will be made available to qualified investigators upon request, provided they can meet the data security requirements of the institutional review boards of the institutions contributing samples to this study.

# %% [markdown]
# # Hard Data

# %% [markdown]
# ## Patient Data

# %% [markdown]
# ### 1) Summary of Prevalence Screen for Intrahepatic Cholangiocarcinomas

# %%
# Summary of Prevalence Screen for Intrahepatic Cholangiocarcinomas

# read in csv file, skipped footer that contained total and percentage
ad = pd.read_csv(PATH + 'Summposps.2813-S3-1.csv', skip_footer=3)
# formatted into preferential columns
ll = ad[['Samples','Sex','Age','Ethnicity', 'Grade','Stage*']]
ll.rename(columns={'Stage*':'Stage','Samples':'Patient_ID','Sex':'Gender'}, inplace=True)
# add cancer tissue column
ll['Tissue'] = 'Intrahepatic Cholangiocarcinomas'
# write to csv file in Pat Data folder
ll.to_csv('/cellar/users/talejand/Documents/IdekerLab/CancerPapers/PatData/patcharExBAP1-IC.csv')
ll
# Out:
# /cellar/users/talejand/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:615: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   ParserWarning)
# /cellar/users/talejand/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2194: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   **kwargs)
#    Patient_ID Gender  Age Ethnicity  Grade Stage  \
# 0       ICC10      M   67     White      2     I
# 1       ICC12      M   70     White      2   IVa
# 2       ICC19      F   75     White      2     I
# 3       ICC20      F   43     White      2   IVa
# 4       ICC22      M   64     White      3     I
# 5       ICC24      F   71     White      2   IVa
# 6       ICC25      F   79     White      2    II
# 7       ICC29      M   67     White      2     I
# 8       ICC31      M   68     White      2   IVa
# ...

# %% [markdown]
# ### 2) Summary of Prevalance Screen for Gallbladder Carcinoma

# %%
# Summary of prevalance screen for Gallbladder Carcinoma

# use columns of interest, and skipped footer that included totals and percentage
br = pd.read_csv(PATH + 'SummpospsT.2813-S3-1.csv', usecols=['Samples','Sex','Age','Ethnicity','Grade','Stage*'], skip_footer=2)
#rename columns to format
br.rename(columns={'Stage*':'Stage','Samples':'Patient_ID','Sex':'Gender'}, inplace=True)
# create tissue column
br['Tissue'] = 'Gallbladder Carcinoma'
# write to csv file in PatData folder
br.to_csv('/cellar/users/talejand/Documents/IdekerLab/CancerPapers/PatData/patcharExBAP1-GallBlad.csv')

br
# Out:
# /cellar/users/talejand/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:615: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   ParserWarning)
#   Patient_ID Gender  Age Ethnicity  Grade Stage                 Tissue
# 0       GB70      M   73     White      2    II  Gallbladder Carcinoma
# 1       GB71      F   59     White      2  IIIb  Gallbladder Carcinoma
# 2       GB72      M   60     White      2    II  Gallbladder Carcinoma
# 3       GB75      M   64     White      2    II  Gallbladder Carcinoma
# 4       GB77      M   76     White      2  IIIb  Gallbladder Carcinoma
# 5      GB117      F   72     White      3  IIIb  Gallbladder Carcinoma
# 6      GB118      M   69     White      1  IIIb  Gallbladder Carcinoma
# 7      GB121      M   75     White      3  IIIb  Gallbladder Carcinoma

# %% [markdown]
# ## Mutation Data

# %% [markdown]
# ### 1) Somatic mutations in intrahepatic cholangiocarcinoma and gallbladder carcinoma

# %%
# Discovery Screen somatic mutations in intrahepatic cholangiocarcinoma and gallbladder carcinoma
df = pd.read_csv(PATH + 'Somaposp.csv')
# format data 
a=df.rename(columns={'Gene ID':'Gene_ID','Tumor Sample':'Tumor_ID','Gene Symbol' : 'Gene','Nucleotide (genomic)' : 'Genome_Change','Mutation type*' : 'Mutation_Category','Amino Acid':'Protein_Change'})
b= a.dropna(subset=['Genome_Change'])
# write to csv file in MutData folder
b.to_csv('/cellar/users/talejand/Documents/IdekerLab/CancerPapers/MutData/mutdataExBAP1.csv')
b.query('Gene == "TP53"')
##b[b['Genome_Change'].str.contains('g.chr1:')] ## gets the entries in the genomechange column that are of g.chr9 so sort by chromosome
# Out:
#       Gene          Gene_ID Tumor_ID                 Genome_Change  \
# 1758  TP53  ENSG00000141510   CHOL08            g.chr17:7518957A>T
# 1759  TP53  ENSG00000141510   CHOL12            g.chr17:7517809T>A
# 1760  TP53  ENSG00000141510     GB07            g.chr17:7519131C>T
# 1761  TP53  ENSG00000141510     GB10  g.chr17:7520127_7520128delAG
# 1762  TP53  ENSG00000141510     GB11            g.chr17:7519131C>A
# 1763  TP53  ENSG00000141510     GB18            g.chr17:7517839C>A
# 1764  TP53  ENSG00000141510     GB19            g.chr17:7517580G>A
# 1765  TP53  ENSG00000141510     GB23            g.chr17:7518937G>A
#
#      Protein_Change Mutation_Category
# 1758        p.L206X               SBS
# 1759        p.E285V               SBS
# 1760        p.R175H               SBS
# 1761          Indel               DEL
# 1762        p.R175L               SBS
# 1763        p.C275F               SBS
# 1764        p.Q331X               SBS
# 1765        p.R213X               SBS

# %% [markdown]
# ### PatMerge

# %%
merge = pd.merge(ll, br, how='outer')
merge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6670c00defdd> in <module>()
# ----> 1 merge = pd.merge(ll, br, how='outer')
#       2 merge
#
# NameError: name 'll' is not defined

# %% [markdown]
# ## Copy Number Data: NA

# %% [markdown]
# ## Other Data

# %%
a
# Out:
#                                                                                                                              Gene ID  \
# Gene
# ABCA1                                                                                                                ENSG00000165029
# ABCB1                                                                                                                ENSG00000085563
# ABCB11                                                                                                                     NM_003742
# ABCG8                                                                                                                ENSG00000143921
# ABHD8                                                                                                                ENSG00000127220
# AC010872.2                                                                                                           ENSG00000218819
# ...

# %%
a.sort(['Protein_Change','Mutation_Category'], ascending=[1,0])
# Out:
#                                                                                                                              Gene ID  \
# Gene
# AGO2                                                                                                                 ENSG00000123908
# BAP1                                                                                                                 ENSG00000163930
# CRELD1                                                                                                               ENSG00000163703
# CSMD3                                                                                                                ENSG00000164796
# DDX41                                                                                                                ENSG00000183258
# FAM171B                                                                                                              ENSG00000144369
# ...

# %%
a.sort(columns='Mutation_Category', ascending=False)
# Out:
#                                                                                                                              Gene ID  \
# Gene
# ACAA2                                                                                                                ENSG00000167315
# ACACA                                                                                                                ENSG00000132142
# ACTR3B                                                                                                               ENSG00000133627
# ADAM28                                                                                                               ENSG00000042980
# ADAMTSL1                                                                                                             ENSG00000178031
# ADCK5                                                                                                                ENSG00000173137
# ...

# %%
## bar plot for mutation types

df['Mutation type*'].value_counts()[:].plot(kind='bar')

# %%
df['Mutation type*'].value_counts()[:].hist()

# %%
df.sort(columns='Amino Acid')
# Out:
#                                                                                                                              Gene ID  \
# Gene Symbol
# ADAMTSL3                                                                                                             ENSG00000156218
# ADRA2B                                                                                                               ENSG00000222040
# AGO2                                                                                                                 ENSG00000123908
# ALS2CR8                                                                                                              ENSG00000138380
# AP000525.1                                                                                                           ENSG00000206252
# APOE                                                                                                                 ENSG00000130203
# ...

# %%
df[['Mutation type*']]
# Out:
#                                                                                                                     Mutation type*
# Gene Symbol
# ABCA1                                                                                                                          SBS
# ABCB1                                                                                                                          SBS
# ABCB11                                                                                                                         SBS
# ABCG8                                                                                                                          SBS
# ABHD8                                                                                                                          SBS
# AC010872.2                                                                                                                     SBS
# ...

# %%
g =br.groupby(['Grade','Age'])

# %%
br.Age[:].sort('Sex')
br
# Out:
#         Sex Age Ethnicity Grade Stage*  AKT1  \
# Samples
# GB70      M  73     White     2     II   NaN
# GB71      F  59     White     2   IIIb   NaN
# GB72      M  60     White     2     II   NaN
# GB75      M  64     White     2     II   NaN
# GB77      M  76     White     2   IIIb   NaN
# GB117     F  72     White     3   IIIb   NaN
# GB118     M  69     White     1   IIIb   NaN
# GB121     M  75     White     3   IIIb   NaN
# Total     -   -         -     -      -     0
# %         -   -         -     -      -     0
#
#                                           ARID1A   BAP1 CDKN2A  CTNNB1  \
# Samples
# GB70                                         NaN    NaN    NaN     NaN
# GB71     c.2879-1G>A        splice site acceptor    NaN   R80X     NaN
# GB72                                         NaN    NaN    NaN     NaN
# GB75                                         NaN    NaN    NaN     NaN
# GB77                                         NaN    NaN    NaN     NaN
# ...

# %%
br.Age
# Out:
# Samples
# GB70       73
# GB71       59
# GB72       60
# GB75       64
# GB77       76
# GB117      72
# GB118      69
# GB121      75
# Total       -
# %           -
# Name: Age, dtype: object

# %%
ad.T.sort()
# Out:
# Samples    ICC10  ICC12                                       ICC19  ICC20  \
# AKT1         NaN    NaN                                         NaN    NaN
# ARID1A       NaN    NaN                                         NaN    NaN
# Age           67     70                                          75     43
# BAP1         NaN    NaN  c.68-2A>G             splice site acceptor    NaN
# CDKN2A       NaN    NaN                                         NaN    NaN
# CTNNB1       NaN    NaN                                         NaN    NaN
# Ethnicity  White  White                                       White  White
# Grade          2      2                                           2      2
# IDH1         NaN    NaN                                         NaN    NaN
# IDH2         NaN    NaN                                       R172S    NaN
# KRAS         NaN    NaN                                         NaN    NaN
# ...

# %%
a= ad.sort('Size (cm)', ascending=False)
b= a.sort('Grade', ascending=False)
c= b.sort("Stage*", ascending=False)
c
# Out:
#                                                                                                                                                                                           Sex  \
# Samples
# ICC32                                                                                                                                                                                       F
# ICC47                                                                                                                                                                                       F
# ICC26                                                                                                                                                                                       M
# ICC12                                                                                                                                                                                       M
# ...
