# %% [markdown]
# # Activating ESR1 mutations in hormone-resistant metastatic breast cancer

# %% [markdown]
# ## Patient Analysis

# %% [markdown]
# * 11 w/ ER+ metastatic breast cancer
#     * 6/11 patients w/ ESR1 mutation
#     * WES and Transcriptome Analysis
#     * 3 of cases primary diagnostics showed ESR1 mutations were not present at an earlier stage, indicating that they were aquired after endocrine therapy

# %% [markdown]
# ## Mutation Analyis

# %% [markdown]
# * 39 gene fusions in the 6 index patients
#     * 11 encoding in frame fusion proteins
#
# * The most notable observation in the mutational landscapes of these treated patients with ER-positive breast cancer was the finding of nonsynonymous mutations in ESR1 affecting the LBD (n = 6).
#     * The six index patients MO_1031, MO_1051, MO_1069, MO_1129, MO_1167 and MO_1185 had mutations encoding p.Leu536Gln, p.Tyr537Ser, p.Asp538Gly, p.Tyr537Ser, p.Asp538Gly and p.Tyr537Ser alterations in the LBD, respectively

# %% [markdown]
# ## Summary

# %% [markdown]
# * ESR1 Mutations in 6/11 patients:
#      * affects ligand binding domain (5 LBD alterations identified)
#      * all had been prev. treated w/ anti-estrogens and estrogen deprivation therapies
#          * Each occurred in the vicinity of the synthetic alterations of ESR1 that are inverted in response to tamoxifen and involve p.Met543Ala and p.Leu544Ala alterations (Inv-mut-AA2)15 and served as a positive control for our subsequent in vitro studies
#             * After looking at TCGA, Here we took advantage of data from the TCGA Project, which has generated whole-exome sequences for 27 tumor types across at least 4,000 individual samples. As expected, LBD-disrupting mutations of ESR1 were not detected in the 390 ER-positive breast cancers sequenced by TCGA, as these were primary resection samples before hormonal treatment16, nor did we detect ESR1 mutations in a cohort of 80 triple-negative breast carcinoma transcriptomes
#
# * 5 LBD-localized ESR1 non-synonymous mutations
#     * p.Leu536Gln, p.Tyr537Ser, p.Tyr537Cys, p.Tyr537Asn and p.Asp538Gly
#         * resulted in constitutive activity and continued responsiveness to anti-estrogen therapies in vitro
#         * Each occurred in the vicinity of the synthetic alterations of ESR1 that are inverted in response to tamoxifen and involve p.Met543Ala and p.Leu544Ala alterations (Inv-mut-AA2) 15 and served as a positive control for our subsequent in vitro studies.
# * <b>Suggests</b>: Activating mutations in ESR1 are a key mechanism in acquired endocrine resistance in breast cancer therapy.

# %% [markdown]
# <figure>
#
#
# 							<figcaption><span class="legend">
# 					Table 1: Clinical sequencing of 11 metastatic ER-positive breast cancer cases				</span></figcaption>
#
#
#
#
# 			<div class="item-content box">
#
# 															<div class="table-wrapper">															<table class="data">
# 																																																<colgroup><col><col><col><col><col><col></colgroup><thead><tr><th class="last rowsep">Case</th><th class="last rowsep">Age (years)</th><th class="last rowsep">ER/PR/ERBB2</th><th class="last rowsep">Treatment<sup><a href="#t1-fn2">a</a></sup></th><th class="last rowsep">Number of SNVs/fusions</th><th class="last rowsep">Genetic aberration<sup><a href="#t1-fn3">b</a></sup></th></tr></thead>
# 																																																																											<tfoot><tr><td colspan="6"><div id="t1-fn1" class="footnote"><p>PR, progesterone receptor; SNVs, single-nucleotide variants.</p></div></td></tr><tr><td colspan="6"><div id="t1-fn2" class="footnote"><p><sup>a</sup>Only anti-estrogen–related treatments are listed. Patients also received chemotherapies, radiation or mastectomy in the interim between diagnosis and MI-ONCOSEQ sequencing.</p></div></td></tr><tr><td colspan="6"><div id="t1-fn3" class="footnote"><p><sup>b</sup>Amino acid substitutions caused by nonsynonymous somatic mutations are given in parentheses.</p></div></td></tr><tr><td colspan="6" class="last"><div id="t1-fn4" class="footnote"><p><sup>c</sup>TP_2004 is male.</p></div></td></tr></tfoot>
# 																																																																			<tbody>																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																
td></tr>
# 																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																																<tr class="alt"><td class="first-cell">TP_2004<sup><a href="#t1-fn4">c</a></sup></td><td>52</td><td>+/−/−</td><td>Tamoxifen (short)</td><td>29/22</td><td><i>MDM2</i> gene amplification, gene copy losses of <i>CDKN2A</i> and <i>CDKN2B</i></td></tr>
# 																																											</tbody>							</table>
# 											</div>
# 																				</div>
#
#
#
#
# 			<nav>				<ul class="figure-nav">
# 										<li class="index only"><a href="/ng/journal/v45/n12/fig_tab/ng.2823_ft.html">Figures/tables index</a></li>
# 									</ul>
# 			</nav>
#
#
# 					</figure>

# %% [markdown]
# ### Accession Codes:

# %% [markdown]
# <b>Accession Codes:</b> Sequence data have been deposited in the database of Genotypes and Phenotypes (dbGaP), which is hosted by the National Center for Biotechnology Information (NCBI), under accessions <b>phs000602.v1.p1 and phs000673.v1.p1.</b>

# %% [markdown]
# ## Hard Data

# %%
import NotebookImport
from Imports import *
# Out:
# importing IPython notebook from <a href='./Imports.ipynb' target='_blank'>Imports</a>
# Populating the interactive namespace from numpy and matplotlib

# %%
PATH = '{}/{}/Activating ESR1 mutations in \
hormone-resistant metastatic breast cancer/'.format(LOCAL_DIR, PAPERS)

# %% [markdown]
# ### Patient Data

# %% [markdown]
# * Copied table 1 of paper onto excel sheet and added a column for gender, all female, but last is male
# * used select columns and skipped footer of male patient with no mutdata
# * why warning with skipping footer?

# %%
a = pd.read_csv(PATH + 'patcharTable1.csv', usecols=['Case','Age','Gender'], skip_footer=1)
a.rename(columns={'Case':'Patient_ID'}, inplace=True)
a.to_csv(MUT_PATH + 'patcharActESR1.csv')
a.head()
# Out:
# /cellar/users/talejand/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:615: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   ParserWarning)
#   Patient_ID  Age Gender
# 0    MO_1031   41      F
# 1    MO_1051   31      F
# 2    MO_1069   62      F
# 3    MO_1129   44      F
# 4    MO_1030   78      F

# %% [markdown]
# ### Mutation Data

# %% [markdown]
# * Might want to usecols=['Gene','Protein_Change','Case_ID', 'Chr'])
# * Genome Change addition function thing does not work the way I want to
# * want to add things in multiple columnns together to get genome change

# %% [markdown]
# ##### 1) Nonsynonymous somatic mutations identified in index cases MO_1031, MO_1051, MO_1069, MO_1129, MO_1167, and MO_1185

# %%
df = pd.read_csv(PATH + 'Nonsomamut6cases.csv', sep = '\t')
df.rename(columns={'Case_ID':'Patient_ID'}, inplace=True)
df.apply(lambda x: x.str.strip())
df.dropna(inplace=True)
df['Genome_Change'] = 'g.chr:' + str(lambda x: x in df.Chr) \
    + str(lambda x: x in df.Coord)+ str(lambda x: x in df.Ref) + '>' \
    + str(lambda x: x in df.Var)
df.to_csv(MUT_PATH + 'mutdataactESR16nonsynsom.csv')
df.head()
# Out:
#     Patient_ID    Gene Protein_Change Chr      Coord Ref Var Present_in_FFPE  \
# 262    MO_1051  CTNNA1        p.D814N   5  138268583   G   A              NO
# 263    MO_1051    TOP1        p.E289K  20   39726867   G   A              NO
# 264    MO_1051    TOP1        p.K321N  20   39726965   G   C              NO
# 265    MO_1051    MAP4        p.E327Q   3   47933003   C   G              NO
# 266    MO_1051    TP53        p.G199E  17    7578253   C   T              NO
#
#      Expression(FPKM)                                      Genome_Change
# 262             146.0  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 263              45.1  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 264              45.1  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 265              41.3  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 266              18.3  g.chr:<function <lambda> at 0x7f73641bb140><fu...

# %% [markdown]
# ### Merged Data

# %% [markdown]
# * 4 cases (most likely non-indexed ones) have NO data
# * 1 thing i will say is that there are protein changes in this dataset that say splice acceptor/donor ?

# %%
merged = pd.merge(a, df, how='outer')
merged.dropna(inplace=True)
merged['Tissue'] = 'Hormone-Resistant Metastatic Breast Cancer'
merged.to_csv(MERGED_PATH + 'mergedActESR1.csv')
merged.head()
# Out:
#   Patient_ID  Age Gender    Gene Protein_Change Chr      Coord Ref Var  \
# 1    MO_1051   31      F  CTNNA1        p.D814N   5  138268583   G   A
# 2    MO_1051   31      F    TOP1        p.E289K  20   39726867   G   A
# 3    MO_1051   31      F    TOP1        p.K321N  20   39726965   G   C
# 4    MO_1051   31      F    MAP4        p.E327Q   3   47933003   C   G
# 5    MO_1051   31      F    TP53        p.G199E  17    7578253   C   T
#
#   Present_in_FFPE  Expression(FPKM)  \
# 1              NO             146.0
# 2              NO              45.1
# 3              NO              45.1
# 4              NO              41.3
# 5              NO              18.3
#
#                                        Genome_Change  \
# 1  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 2  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 3  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# 4  g.chr:<function <lambda> at 0x7f73641bb140><fu...
# ...

# %%
plot_age_gender(merged)

# %%
plot_gene_protein(merged)

# %% [markdown]
# ### Copy Number Data

# %% [markdown]
# ###### 1) Gene Copy Number Gains and Losses in 6 index cases

# %%
copynum6cases = pd.read_table(PATH + 'copynum6cases.csv', index_col=0, sep = '\t')
copynum6cases.drop(['MiOncoSeq_Panel_Genes','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'], 1, inplace=True)
copynum6cases
# Out:
#         Chr  Loc_Start    Loc_End  #_Exon_Targets  Adj_Copy_#_Ratio
# Case_ID
# MO_1031  10   17130256   17432516              45              8.28
# MO_1031  10   81316935   84498366              95              8.26
# MO_1031  11   92881856   92931012              11              7.77
# MO_1031   4   68919654   69107468              22              7.59
# MO_1031   8   33230180   33251814               3              7.50
# MO_1031  10   74451906   75530518             186              7.17
# MO_1031  10   76154036   77312230              59              6.79
# MO_1031  11   69456232   70196120              71              6.75
# MO_1031   8   35401916   38599900             236              6.74
# MO_1031  10   12802948   13568184              72              6.69
# MO_1031  10   11551638   12272906              88              6.57
# MO_1031  18    6171882    6263988               9              6.46
# MO_1031  10  123233969  123629536              27              6.32
# ...

# %% [markdown]
# ### Other Data

# %% [markdown]
# ###### 1) Gene Fusions identified in six index cases

# %%
genefus6 = pd.read_csv(PATH + 'genefus6cases.csv', index_col=0, sep = '\t')
genefus6
# Out:
#               5'Gene  Chr  hg19position          3'Gene  Chr.1  \
# Sample_ID
# MO_1031        SFRP1    8      41161056     ST8SIA6-AS1     10
# MO_1031     PLA2G12A    4     110650757         COL15A1      9
# MO_1031       USP6NL   10      11551593           UNC5D      8
# MO_1031         PPIF   10      81111338      AL359195.1     10
# MO_1031        RAB10    2      26257603          SPTBN1      2
# MO_1031       NT5C3L   17      39991321         SPATS2L      2
# MO_1031    RAB11FIP1    8      37727937           CCDC3     10
# MO_1031       LRRC56   11        540132           NELL1     11
# MO_1031        CADM2    3      85851345           CCDC3     10
# MO_1031         IPO9    1     201817721          PM20D1      1
# MO_1031          NLK   17      26459834    AC015849.2.1     17
# MO_1031         STAM   10      17686377           CADM2      3
# MO_1031    ARSJ (AS)    4     114880675          TBC1D9      4
# MO_1031         EVI5    1      93029198          PRKACB      1
# ...
